# %% [markdown]
# # Swendsen-Wang dynamics for Ising model
#
# _(using torch)_

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider
import ipywidgets as widgets
import importlib
import sys

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# drive/  sample_data/

# %%
filehandle_ebgfn = 'drive/Othercomputers/numac/GitHub/EB_GFN/'
sys.path.insert(0, filehandle_ebgfn)

# %%
import ising_utils_torch
importlib.reload(ising_utils_torch)
# Out:
# <module 'ising_utils_torch' from '/content/drive/Othercomputers/numac/GitHub/EB_GFN/ising_utils_torch.py'>

# %%
# re-set parameters if one wants
N = 20          # Lattice size
"""
T_c (Isng, dim=2) is approx 2.269
beta_c is thus approx 0.441
beta > beta_c is "low temperature phase"
beta < beta_c is "high temperature phase"
""";
beta = 0.441      # Inverse temperature,
steps = 100   # Number of steps

# %%
# Initialize and simulate
importlib.reload(ising_utils_torch)
lattice = ising_utils_torch.initialize_lattice(N)
snapshots_SW, bond_snapshots_SW = ising_utils_torch.simulate_swendsen_wang_interactive(lattice, beta,steps)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2f6fb3eff6ec> in <cell line: 4>()
#       2 importlib.reload(ising_utils_torch)
#       3 lattice = ising_utils_torch.initialize_lattice(N)
# ----> 4 snapshots_SW, bond_snapshots_SW = ising_utils_torch.simulate_swendsen_wang_interactive(lattice, beta,steps)
#
# /content/drive/Othercomputers/numac/GitHub/EB_GFN/ising_utils_torch.py in simulate_swendsen_wang_interactive(lattice, beta, steps)
#      94     for step in range(steps):
#      95         if step % 2 == 0:  # Bond update step
# ---> 96             uf, horizontal_bonds, vertical_bonds = update_bonds(lattice, beta)
#      97             bond_snapshots.append((horizontal_bonds.clone(), vertical_bonds.clone()))  # bond snapshot after bond update
#      98             lattice_snapshots.append(lattice.clone())  # spin snapshot after bond update
#
# /content/drive/Othercomputers/numac/GitHub/EB_GFN/ising_utils_torch.py in update_bonds(lattice, beta)
#      55                 vertical_bonds[i, j] = True
#      56             # Only create a horizontal bond if the spins are the same and within bounds
# ---> 57             if j < N - 1 and lattice[i, j] == lattice[i, j + 1] and torch.rand(1).item() < 1 - torch.exp(-2 * beta).item():
#      58                 uf.union(i * N + j, i * N + j + 1)
#      59                 horizontal_bonds[i, j] = True
#
# TypeError: exp(): argument 'input' (position 1) must be Tensor, not float

# %%
# Create interactive plot
importlib.reload(ising_utils_torch)
interact(ising_utils_torch.plot_lattice_with_bonds,
         lattice_snapshots=widgets.fixed(snapshots_SW),
         bond_snapshots=widgets.fixed(bond_snapshots_SW),
         step=IntSlider(min=0,
                        max=len(snapshots_SW)-1,
                        step=1,
                        value=0),
         figsize=widgets.fixed((10, 10)));

# %%
# here is the interactive plot without the bonds
importlib.reload(ising_utils_torch)
interact(ising_utils_torch.plot_lattice,
         lattice=widgets.fixed(snapshots_SW),
         step=IntSlider(min=1,
                        max=len(snapshots_SW)-1,
                        step=2, # because we alternate bond and site updates
                        value=0));
